# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv('/content/drive/MyDrive/MLDataSets/Price.csv')
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
.%matplotlib inline
plt.xlabel('area(sq.ft)')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
reg = LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# y = mx + c
135.7876*3000 + 180616.4383
# Out:
# 587979.2383

# %%
df2 = pd.read_csv('/content/drive/MyDrive/ML DataSets/areas.csv')
df2.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
ar = reg.predict(df2)
ar
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         916585.61643836,  645010.2739726 ,  821534.24657534,
#         520085.61643836, 1402705.47945205, 1266917.80821918,
#         348178.42465753])

# %%
df2['price'] = reg.predict(df2[['area']])
ar = df2['price']

# %%
ar.to_csv("areas.csv")
df2.head()
# Out:
#    area          price
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836

# %%
# %matplotlib inline
plt.xlabel('area(sq.ft)')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
